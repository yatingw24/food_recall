# %% [markdown]
# # set up and load the data

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/anesta95/food_safety_recalls/refs/heads/main/clean_data/food_safety_recalls.json"
# Read the JSON file into a DataFrame
df = pd.read_json(url)

df
# Out:
#                                                  title  \
# 0    Lyons Magnus Recalls Lyons ReadyCare and Sysco...
# 1    Kayco Issues an Allergy Alert on Undeclared Mi...
# 2    Kedake Inc. Issues Allergy Alert on Undeclared...
# 3    ZB Importing Issue Voluntary Recall and Allerg...
# 4    Naturipe Value Added Fresh LLC Issues Allergy ...
# ..                                                 ...
# 96   TreeHouse Foods Announces Voluntary Recall of ...
# 97   Dakota Tom’s Sandwiches Recalls Pepperjack Che...
# 98   Enoki King Mushroom Farm Recalls Enoki Because...
# 99   Tipical Latin Food, Corp. Issues Allergy Alert...
# 100  Albertsons Companies Voluntarily Recalls 12 Re...
#
#          company_announce_dttm          notification_dttm  \
# 0    2025-02-22T18:18:00+00:00  2025-02-23T05:00:00+00:00
# 1    2025-02-21T21:52:00+00:00  2025-02-21T05:00:00+00:00
# 2    2025-02-20T21:19:00+00:00  2025-02-20T05:00:00+00:00
# 3    2025-02-18T18:12:00+00:00  2025-02-20T05:00:00+00:00
# ...

# %%
df[df['agency'] == 'FDA']
# Out:
#                                                  title  \
# 0    Lyons Magnus Recalls Lyons ReadyCare and Sysco...
# 1    Kayco Issues an Allergy Alert on Undeclared Mi...
# 2    Kedake Inc. Issues Allergy Alert on Undeclared...
# 3    ZB Importing Issue Voluntary Recall and Allerg...
# 4    Naturipe Value Added Fresh LLC Issues Allergy ...
# ..                                                 ...
# 96   TreeHouse Foods Announces Voluntary Recall of ...
# 97   Dakota Tom’s Sandwiches Recalls Pepperjack Che...
# 98   Enoki King Mushroom Farm Recalls Enoki Because...
# 99   Tipical Latin Food, Corp. Issues Allergy Alert...
# 100  Albertsons Companies Voluntarily Recalls 12 Re...
#
#          company_announce_dttm          notification_dttm  \
# 0    2025-02-22T18:18:00+00:00  2025-02-23T05:00:00+00:00
# 1    2025-02-21T21:52:00+00:00  2025-02-21T05:00:00+00:00
# 2    2025-02-20T21:19:00+00:00  2025-02-20T05:00:00+00:00
# 3    2025-02-18T18:12:00+00:00  2025-02-20T05:00:00+00:00
# ...

# %%
# Light Analysis
